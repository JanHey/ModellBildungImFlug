# %% [markdown]
# # Hallo Mensch!
#
# Schön, dass du hier bist! In dieser Programmierumgebung erwarten dich vier Teile, die wir "Meilensteine" nennen:
#
# 1) Erst lernst du diese Umgebung kennen. Erschrick bitte nicht, falls du noch nie programmiert hast! Wir setzten keine Programmierkenntnisse voraus und zeigen dir alles, was du wissen musst, im Abschnitt des ersten Meilensteins.
# 2) Videoanalyse: du liest das von dir aufgenommene Video ein und führst eine Videoanalyse durch.
# 3) Simulation: du simulierst die Wurfbewegung mit einem Modell.
# 4) Vergleich von Beobachtung und Simulation: du vergleichst deine Beobachtung aus der Videoanalyse mit dem Ergebnis der Simulation, um dein Modell, auf dem die Simulation beruht, zu bewerten. Wenn Simulation und Beobachtung nicht gut zusammen passen, kannst du dein Modell ändern oder erweitern.
#
# Los geht´s!

# %% [markdown]
# # Meilenstein 1: Kennenlernen der Umgebung
#
# Du hast noch nie mit solch einer Umgebung gearbeitete? Kein Problem! Diese kurze Einführung zeigt dir alles, was du wissen musst, um hiermit zu arbeiten. Lies einfach die Punkte in dieser Einführung und führe die Aufträge darin aus! Falls du Fragen hast, wende dich an deine Lehrkraft oder an Jan Heysel an der Uni Bonn (jan.heysel@uni-bonn.de oder 0228 73 2269).

# %% [markdown]
# ### Schritt 1:
# Text, der so gedruckt ist wie hier oder der hinter einer Raute / Hashtag ("#") steht, ist ein Kommentar für dich als Mensch. Der Computer macht nichts damit.
# Zellen, neben denen "In [ ]" steht, sind "Code-Zellen". Der Text darin ist eine Anweisung an den Computer. Diese Anweisungen sind in der Programmiersprache Python geschrieben. Wenn du auf das Playsymbol links von der Zelle drückst (falls du an einem iPad arbeitest) oder 'Umschalt' und 'Enter' (falls du eine Tastatur vor dir hast) führt der Computer diese Eingaben aus. Das heißt, du sagst dem Computer, dass er das machen soll, was in der Zelle steht.
#
#
# Ein Beispiel: in der folgenden Zelle steht für den Computer, dass er "Hallo Welt." drucken soll (engl. "print" = drucken). Drücke einmal auf das Play-Symbol links neben der Zelle (wenn du in der App auf einem iPad arbeitest) oder 'Umschalt' und 'Enter' gleichzeitig (wenn du eine Tastatur vor dir hast), um dem Computer den Befehl zu geben. Probiere es aus!

# %%
print("Hallo Welt.")
# Out:
# Hallo Welt.

# %% [markdown]
# ### Schritt 2: Variablen definieren
# Variablen kennst du vermutlich aus dem Mathe- oder Physikunterricht. Variablen sind Platzhalter, die verschiedene Werte annehmen können. Aus Mathe kennst du vermutlich Variablen, die für Zahlen stehen. Das geht hier auch. Außerdem können Variablen hier auch für andere Inhalte stehen. Z.B. für Text. Solchen Text schreiben wir in Anführungszeichen, damit der Computer weiß, dass wir Text meinen.
#
# Beispiel: Belege die Variablen "Name" mit deinem Namen und die Variable "a" mit deinem Alter. Kannst du erraten, was der Computer ausgibt, wenn du die folgende Zelle ausführst? Führe die Zelle dann aus.

# %%
a = 16
Name = "Test"

print("Hallo " + Name + ".")
print(str(a) + " ist ein schönes Alter.")
# Out:
# Hallo Test.
# 16 ist ein schönes Alter.

# %% [markdown]
# ### Schritt 3: Rechnen
# Natürlich kann ein Computer auch rechnen. Trage für die Variable "b" das Alter einer Partner:in ein, mit der du gerade zusammenarbeitest. Führe dann die Zelle aus.

# %%
b = 15
c = a + b

print("Zusammen seid ihr " + str(c) + " Jahre alt.")
# Out:
# Zusammen seid ihr 31 Jahre alt.

# %% [markdown]
# Du hast nun gelernt, wie du dem Computer in der Programmiersprache Python Befehle geben und diese ausführen kannst, wie du Variablen festlegen kannst und dass der Computer damit rechnen kann. Für diese Simulationsumgebung reicht das schon! Du hast den ersten Meilenstein erreicht!
#
# Mache dich nun auf zum zweiten Meilenstein, der Videoanalyse!

# %% [markdown]
# # Meilenstein 2: Videoanalyse
#
# Du hast bereits ein Video einer Wurfbewegung aus einer Sportart aufgenommen (falls doch nicht, mach dies zuerst). Dieses Video analysieren wir nun, mit zwei Zielen:
# - Wir bestimmen Schätzwerte für den Ort und die Geschwindigkeit (je in x- und y-Richtung), die das Objekt zu Beginn der freien Flugbewegung haben. Diese Werte nennen wir "Anfangswerte". Wir benötigen diese Werte später, um die Flugkurve zu simulieren.
# - Wir erhalten Messwerte der Flugkurve. Mit diesen Messwerten vergleichen wir am Ende unsere Simulation, um zu überprüfen, wie gut Simulation und Beobachtung zusammenpassen.
#
# Und so geht es los:
# 1) Stelle sicher, dass das Video, dass du aufgenommen hast, wirklich genau zeitlich und räumlich zugeschnitten ist. Zeitlich zugeschnitten meint: bereits auf dem ersten Bild des Videos sollte sich das Objekt frei bewegen, also die abwerfende Hand verlassen haben. Räumlich zugeschnitten meint: die von dir gemessene Breite B ist tatsächlich die Breite des Bildausschnitts in der Realität.
# 2) Übertrage das Video auf das Gerät, auf dem du gerade arbeitest.
# 3) Lade das Video in diese Umgebung hoch.
# 4) Trage nun die Bildbreite B und den Dateinamen des Videos in der Zelle hierunter ein. Beachte hierbei: Gib die Bildbreite in der Einheit Meter an, aber nur die Zahl. Statt eines Kommas mache einen Punkt, wie im Beispiel (amerikanische Schreibweise von Kommazahlen). Um den Dateinamen sollten Anführungszeichen stehen, wie bei dem Beispiel. Gib den Dateinamen einschließlich Dateiendung ein. Beachte Groß- und Kleinschreibung. Der Dateiname darf keine Leerzeichen enthalten. Falls der Dateiname Leerzeichen enthält, ändere ihn zuerst.
# 5) Führe die Zelle hierunter dann aus (auf Tastatur 'Umschalt' und 'Enter' drücken). Unter der Zelle sollten dann die Bildbreite und der Dateiname ausgegeben werden.

# %%
B = 2.0 # Bildbreite in Meter
dateiname_realvideo = "Video_WPH_kurz.mp4"

print("Eingabe Bildbreite: " + str(B) + " m")
print("Eingabe Dateiname Video: " + dateiname_realvideo)
# Out:
# Eingabe Bildbreite: 2.0 m
# Eingabe Dateiname Video: Video_WPH_kurz.mp4

# %% [markdown]
# Im Folgenden geben wir dem Computer verschiedene Informationen, die er braucht, lesen das Video ein und zerlegen es in einzelne Bilder. Bitte führe diese Zelle aus - wie auch immer alle folgenden Zellen. Unter der Zelle sollte dann stehen "Informationen und Video erfolgreich eingelesen". Kümmere dich nicht weiter darum, was in der Zelle genau passiert, sondern gehe weiter zur nächsten Zelle.

# %%
from educhallenge_vX1 import * 
import matplotlib.animation as animation

def onclick(event):
    ix, iy = event.xdata, event.ydata
    x.append(ix)
    y.append(iy)
    return x, y

N_Bilder, fps, h, b, H = vorbereitungen(dateiname_realvideo, B)
# Out:
# Informationen und Video erfolgreich eingelesen.
# Der Bildausschnitt im Realvideo ist 2.0 m breit und 1.125 m hoch.

# %% [markdown]
# Auch in der nächsten Zelle musst du dich nicht darum kümmern, was der Programmcode bedeutet. Wichtig ist für dich:
#
# Unter der Zelle erscheinen gleich alle Bilder, aus denen das Video besteht, das du hochgeladen hast. Klicke in jedem Bild das fliegende Objekt an, das du untersuchen möchtest. Auf diese Weise markierst du die Flugkurve des Objekts.

# %%
fig, ax = define_figure(B, H)
fmes = define_fmes(N_Bilder, B, H)
x = []
y = []

ani = animation.ArtistAnimation(fig, fmes, interval=1500, repeat = False) 
cid = fig.canvas.mpl_connect('button_press_event', onclick)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Wenn du den Ball in allen Bildern angeklickt / angetippt hast, führe auch die folgende Zelle aus, um die Messwerte anzuzeigen und zu speichern.

# %%
N_Punkte = Messwerte_zeigen_und_speichern(x, y, B, H, b, h, fps, N_Bilder)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# geschätzte Anfangswerte der Wurfbewegung:
# x_0=0.14m
# y_0=0.24m
# v_x0=3.08m/s
# v_y0=3.1m/s

# %% [markdown]
# Meilenstein 2, die Videoanalyse, hast du nun fertig. Glückwunsch!
#
# In den beiden Dateien "Videoanalyse_Positionen.xlsx" und "Videoanalyse_Parameter.xlsx" sind deine Werte gespeichert. Lade diese Dateien am besten einmal auf dein lokales Gerät herunter, damit du sie als Sicherung hast, falls du später weiterarbeiten möchtest. Du kannst diese Dateien auch z.B. in Excel öffnen. Falls du an einem anderen Tag hier weiterarbeiten möchtest, kannst du diese Dateien wieder in diese Umgebung hochladen und dann hier weiterarbeiten. Führe dazu einfach die beiden Zellen oben, die mit "B = ... " und mit "from educhallenge_vX1 import *" beginnen sowie die folgende Zelle aus.

# %%
x, y, zeitpunkte, B, H, b, h, fps, delta_t, N_Punkte, N_Bilder, x_0, y_0, v_x0, v_y0 = werte_wiederherstellen()
# Out:
# geschätzte Anfangswerte der Wurfbewegung:
# x_0=0.14m
# y_0=0.24m
# v_x0=3.08m/s
# v_y0=3.1m/s

# %% [markdown]
# ## Bevor du weitermachst, schaue dir erst die beiden Erklärvideos dazu an, was ein naturwissenschaftliches Modell ist.

# %% [markdown]
# # Meilenstein 3: die Simulation
#
# In diesem Abschnitt simulierst du die Wurfbewegung. Hier nutzt du das Modell, das wir dir in dem Erklärvideo vorgestellt haben. In dieser Kurzversion "ModellBildung im Flug" musst du das Modell nicht selber in Rechenvorschriften umsetzen, sondern das ist für dich bereits fertig vorbereitet.
#
# Mit der folgenden Simulation nutzen wir also das Modell aus dem Erklärvideo, in dem das von dir geworfene Objekt nur ein Punkt ist, der sich ohne Luftreibung durch den Raum bewegt. Gib hierunter die Schätzwerte für die Anfangswerte von Ort und Geschwindigkeit in x- und y-Richtung ein, die neben dem Modell die Simulation festlegen. Falls du gerade ein wiederholtes Mal eine Simulation ausführst, erhöhe den Wert von "Nr", um deine früheren Ergebnisse nicht zu überschreiben. Führe dann die Zelle aus, um die Simulation zu starten.

# %%
x_0  = 0.14 # Ort des Balls in x-Richtung am Anfang, Einheit: m
y_0  = 0.24 # Ort des Balls in y-Richtung am Anfang, Einheit: m
v_x0 = 3.00 # Geschwindigkeit des Balls in x-Richtung am Anfang, Einheit: m/s
v_y0 = 2.95 # Geschwindigkeit des Balls in y-Richtung am Anfang, Einheit: m/s

Nr = 1

df_sim = simulation_ausführen(x_0, y_0, v_x0, v_y0, fps, N_Punkte, Nr)
# Out:
# Die Simulation wurde erfolgreich durchgeführt.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Meilenstein 4: Vergleich von Simulation und Messdaten
#
# Du hast nun Messdaten der real beobachteten Flugkurve aus dem Video. Und du hast eine Simulation der Bewegung, die auf einem Modell beruht, also auf einer Vorstellung darüber, wie die Natur funktionieren könnte. Ein naturwissenschaftliches Modell überprüfen wir immer an Beobachtungen. Vergleiche also nun die Ergebnisse deiner Simulation mit deiner Beobachtung! Dazu kannst du nun eine Grafik und ein Video erzeugen lassen, in denen deine beobachteten Messwerte mit den Simulationsergebnissen überlagert werden.
#
# Führe die nächsten beiden Zellen aus, um die Grafik und das Überlagerungsvideo zu erzeugen.

# %%
# Grafik erzeugen
erzeuge_Grafiken(Nr)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Grafik erzeugt.

# %%
# Video erzeugen
erzeuge_Ueberlagerungsvideo(Nr)
# Out:
# Vorbereitungen für Videoerstellung abgeschlossen... (Bilder werden nun erzeugt. Das dauert einen Moment...)
# 18 Einzelbilder der Überlagerungen erzeugt (Zwischenschritt).
# Einzelbilder zu Video zusammengefügt.
# Du findest das Video mit dem Dateinamen > ueberlagerungsvideo__1_15-21-39.mp4 < in dem Unterordner mit eurem Gruppennamen. Schaut es euch einmal an!

# %% [markdown]
# Schaue dir die Grafik und deine Simulation an. Wie gut beschreibt die Simulation die Beobachtung?
#
# Falls Simulationsergebnis und Modell nicht so gut zusammen passen, kannst du folgendes versuchen:
# - Kontrolliere deine Videoaufnahme: ist die Kamera wirklich nicht bewegt? Ist die notierte Breite des Bildausschnitts B richtig gemessen? Gibt es evtl. perspektivisiche Verzerrungen? Fallen dir andere Faktoren ein, die das Experiment beeinflusst haben könnten?
# - Überprüfe deine Simulation: an den voreingestellten Parametern der Simulation kannst du zwar in dieser Mission "ModellBildung im Flug" nichts ändern. Aber überprüfe deine Anfangswerte! Die Ausgabe dazu ist nur ein Schätzwert! Ändere deine Anfangswerte und schaue, ob du Anfangswerte findest, mit denen deine Simulation besonders gut zu der beobachteten Bewegung passt.
#
# Es kann aber auch sein, dass trotz allen Versuchen das Modell mit der Beobachtung in Übereinstimmung zu bringen, dies einfach nicht passt. Dies ist der spannendste Fall! Denn dann heißt es, dass du das Modell erweitern musst!
#
# Wenn du einen solchen Fall gefunden hast, nimm ab Herbst 2023 an der dritten "EduChallenge: ModellBildung" teil, um noch mehr über Modelle zu erfahren und dein Modell so weiterzudenken, dass es möglichst gut zu deiner Beobachtung passt!
#
# Aber zunächst: lade die letzte Grafik und das Video im Forum hoch und ergänze ein paar Notizen, was du gemacht hast und wie du die Übereinstimmung des Modells mit deiner Beobachtung bewertest. Wir sind super gespannt! Mit dem Eintrag im Forum nimmst du außerdem an unserem Gewinnspiel teil.
